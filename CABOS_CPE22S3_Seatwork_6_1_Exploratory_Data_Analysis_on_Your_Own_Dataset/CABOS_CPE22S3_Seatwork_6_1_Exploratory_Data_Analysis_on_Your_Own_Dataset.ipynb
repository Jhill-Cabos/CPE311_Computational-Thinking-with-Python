# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# </center>
#                   Seatwork 6.1 Exploratory Data Analysis on Your Own Dataset </center>
#
# ---
# <center>
#
# | Course: CPE 311 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Computational Thinking with Python | **Date Performed:** 3/11/2024|
# | **Section**:CPE22S3  | **Date Submitted:**|
# | **Student Name**: Jhillian Cabos  | **Instructor's Name:**Roman Richard |
# </center>

# %%
filepath = "/content/laptops.csv"
import pandas as pd
import numpy as np
laptopdata = pd.read_csv(filepath)
laptopdata
from statistics import mean, median, mode, variance, stdev, quantiles

# %% [markdown]
# Making it into a Dataframe

# %%
laptop_df = pd.DataFrame(laptopdata)
laptop_df
# Out:
#      index   brand                                              Model  Price  \
# 0        1   tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1        2   tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2        3      hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 3        4    acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4        5  lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
# ..     ...     ...                                                ...    ...
# 986    998    asus  Asus Vivobook Pro 15 M6500QC-HN542WS Laptop (R...  65990
# 987    999     msi  MSI Thin GF63 12VE-070IN Gaming Laptop (12th G...  91990
# 988   1000    asus  Asus Vivobook Go 15 2023 E1504FA-NJ522WS Lapto...  44990
# 989   1001    asus  Asus Zenbook 14 2023 UM3402YA-KP541WS Laptop (...  67990
# 990   1002      hp  HP Chromebook 15a-na0008TU Laptop (Intel Celer...  20990
#
# ...

# %% [markdown]
# * Sorting it by price

# %%
sortage = laptop_df.sort_values(by='Price')
sortage
# Out:
#      index      brand                                              Model  \
# 77      83      iball  iBall Excelance CompBook Laptop (AQC/ 2GB/ 32G...
# 88      94    ultimus  Ultimus Pro NU14U3INC43BN-CS Laptop (Celeron N...
# 372    384  primebook  Primebook PBMTWIFI11064 Wi-Fi Laptop (MediaTek...
# 192    203        jio  Jio JioBook NB1112MM BLU 2023 Netbook Laptop (...
# 153    164    ultimus  Ultimus Lite NU14U4INC44BN-CS Laptop (Celeron ...
# ..     ...        ...                                                ...
# 845    857       dell  Dell Alienware X16 R1 Gaming Laptop (13th Gen ...
# 22      23      apple  Apple MacBook Pro 16 2023 Laptop (Apple M3 Max...
# 404    416        msi  MSI CreatorPro Z16 HX B13VKTO-214IN Laptop (13...
# 608    620       dell  Dell Alienware M18 R1 2023 Gaming Laptop (13th...
# 601    613       dell  Dell Alienware X16 Gaming Laptop (13th Gen Cor...
#
#       Price  Rating processor_brand processor_tier  num_cores  num_threads  \
# ...

# %% [markdown]
# Here are the columns:

# %%
laptop_df =pd.read_csv(filepath)
(laptop_df.columns)
# Out:
# Index(['index', 'brand', 'Model', 'Price', 'Rating', 'processor_brand',
#        'processor_tier', 'num_cores', 'num_threads', 'ram_memory',
#        'primary_storage_type', 'primary_storage_capacity',
#        'secondary_storage_type', 'secondary_storage_capacity', 'gpu_brand',
#        'gpu_type', 'is_touch_screen', 'display_size', 'resolution_width',
#        'resolution_height', 'OS', 'year_of_warranty'],
#       dtype='object')

# %% [markdown]
# Here are the datatypes:

# %%
datypes = laptop_df.dtypes

print(datypes)
# Out:
# index                           int64
# brand                          object
# Model                          object
# Price                           int64
# Rating                          int64
# processor_brand                object
# processor_tier                 object
# num_cores                       int64
# num_threads                     int64
# ram_memory                      int64
# primary_storage_type           object
# primary_storage_capacity        int64
# secondary_storage_type         object
# secondary_storage_capacity      int64
# gpu_brand                      object
# gpu_type                       object
# is_touch_screen                  bool
# display_size                  float64
# resolution_width                int64
# resolution_height               int64
# OS                             object
# year_of_warranty               object
# dtype: object

# %% [markdown]
# Displaying the total number of records

# %%
laptop_records = laptop_df.shape[0]
laptop_records
# Out:
# 991

# %% [markdown]
# Displaying the first 10 records:

# %%
laptop_df.iloc[0:10]
# Out:
#    index    brand                                              Model  Price  \
# 0      1    tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1      2    tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2      3       hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 3      4     acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4      5   lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
# 5      6    apple  Apple MacBook Air 2020 MGND3HN Laptop (Apple M...  70990
# 6      7  infinix  Infinix INBook Y2 Plus Laptop (11th Gen Core i...  34990
# 7      8     asus  Asus TUF Gaming F15 FX506HF-HN024W Gaming Lapt...  49990
# 8      9       hp  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  36990
# 9     10  infinix  Infinix Zerobook 2023 Laptop (13th Gen Core i9...  59990
#
#    Rating processor_brand processor_tier  num_cores  num_threads  ram_memory  \
# ...

# %% [markdown]
# Last 20 are:

# %%
laptop_df.iloc[-10:]
# Out:
#      index brand                                              Model   Price  \
# 981    993   msi  MSI Katana 15 B13VFK-296IN Gaming Laptop (13th...  119990
# 982    994  asus  Asus Zenbook 14 OLED 2023 UM3402YA-KM551WS Lap...   77990
# 983    995  asus  Asus Vivobook 16 2023 M1605YA-MB551WS Laptop (...   66990
# 984    996  asus  Asus Vivobook 16 2023 M1605YA-MB541WS Laptop (...   59990
# 985    997  acer  Acer Nitro 5 AN515-47 NH.QL3SI.003 Gaming Lapt...   75500
# 986    998  asus  Asus Vivobook Pro 15 M6500QC-HN542WS Laptop (R...   65990
# 987    999   msi  MSI Thin GF63 12VE-070IN Gaming Laptop (12th G...   91990
# 988   1000  asus  Asus Vivobook Go 15 2023 E1504FA-NJ522WS Lapto...   44990
# 989   1001  asus  Asus Zenbook 14 2023 UM3402YA-KP541WS Laptop (...   67990
# 990   1002    hp  HP Chromebook 15a-na0008TU Laptop (Intel Celer...   20990
#
#      Rating processor_brand processor_tier  num_cores  num_threads  \
# ...

# %% [markdown]
# Show the models but only the last 10

# %%
lapdf =pd.read_csv(filepath, index_col ='Model')
laptop_df.iloc[-10:]
lapdf
# Out:
#                                                     index   brand  Price  \
# Model
# Tecno Megabook T1 Laptop (11th Gen Core i3/ 8GB...      1   tecno  23990
# Tecno Megabook T1 Laptop (11th Gen Core i7/ 16G...      2   tecno  35990
# HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen ...      3      hp  51100
# Acer Extensa EX214-53 Laptop (12th Gen Core i5/...      4    acer  39990
# Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300U...      5  lenovo  28580
# ...                                                   ...     ...    ...
# Asus Vivobook Pro 15 M6500QC-HN542WS Laptop (Ry...    998    asus  65990
# MSI Thin GF63 12VE-070IN Gaming Laptop (12th Ge...    999     msi  91990
# Asus Vivobook Go 15 2023 E1504FA-NJ522WS Laptop...   1000    asus  44990
# Asus Zenbook 14 2023 UM3402YA-KP541WS Laptop (R...   1001    asus  67990
# HP Chromebook 15a-na0008TU Laptop (Intel Celero...   1002      hp  20990
#
#                                                     Rating processor_brand  \
# ...

# %% [markdown]
# Getting the Total of all the Laptops in 2024

# %%
Total = laptop_df['Price'].sum()
Total
# Out:
# 76571106

# %% [markdown]
# Sorting the Prices but showing only the first 20:

# %%
sorted_df_by_prices = laptop_df.sort_values(by='Price', ascending=False)
sorted_df_by_prices
# Out:
#      index      brand                                              Model  \
# 601    613       dell  Dell Alienware X16 Gaming Laptop (13th Gen Cor...
# 608    620       dell  Dell Alienware M18 R1 2023 Gaming Laptop (13th...
# 404    416        msi  MSI CreatorPro Z16 HX B13VKTO-214IN Laptop (13...
# 22      23      apple  Apple MacBook Pro 16 2023 Laptop (Apple M3 Max...
# 845    857       dell  Dell Alienware X16 R1 Gaming Laptop (13th Gen ...
# ..     ...        ...                                                ...
# 730    742        axl  AXL Vayu Book LAP01 Laptop (Celeron N4020/ 4GB...
# 192    203        jio  Jio JioBook NB1112MM BLU 2023 Netbook Laptop (...
# 372    384  primebook  Primebook PBMTWIFI11064 Wi-Fi Laptop (MediaTek...
# 88      94    ultimus  Ultimus Pro NU14U3INC43BN-CS Laptop (Celeron N...
# 77      83      iball  iBall Excelance CompBook Laptop (AQC/ 2GB/ 32G...
#
#       Price  Rating processor_brand processor_tier  num_cores  num_threads  \
# ...

# %% [markdown]
# Showing the last 10:

# %%
sorted_df_by_prices.iloc[-10:]
sorted_df_by_prices
# Out:
#      index      brand                                              Model  \
# 601    613       dell  Dell Alienware X16 Gaming Laptop (13th Gen Cor...
# 608    620       dell  Dell Alienware M18 R1 2023 Gaming Laptop (13th...
# 404    416        msi  MSI CreatorPro Z16 HX B13VKTO-214IN Laptop (13...
# 22      23      apple  Apple MacBook Pro 16 2023 Laptop (Apple M3 Max...
# 845    857       dell  Dell Alienware X16 R1 Gaming Laptop (13th Gen ...
# ..     ...        ...                                                ...
# 730    742        axl  AXL Vayu Book LAP01 Laptop (Celeron N4020/ 4GB...
# 192    203        jio  Jio JioBook NB1112MM BLU 2023 Netbook Laptop (...
# 372    384  primebook  Primebook PBMTWIFI11064 Wi-Fi Laptop (MediaTek...
# 88      94    ultimus  Ultimus Pro NU14U3INC43BN-CS Laptop (Celeron N...
# 77      83      iball  iBall Excelance CompBook Laptop (AQC/ 2GB/ 32G...
#
#       Price  Rating processor_brand processor_tier  num_cores  num_threads  \
# ...

# %% [markdown]
# Getting the mean of the Prices of the Laptops in 2024

# %%
meanLap = laptop_df['Price'].mean()
meanLap
# Out:
# 77266.50454086781

# %% [markdown]
# Getting the mean of the Rating:

# %%
meanLapR = laptop_df['Rating'].mean()
meanLapR
# Out:
# 63.9313824419778

# %% [markdown]
# Getting the Median by the Prices:

# %%
medianLap = sorted_df_by_prices['Price'].median()
medianLap
# Out:
# 61900.0

# %% [markdown]
# This time Rating:

# %%
sorted_df_by_rating = laptop_df.sort_values(by='Rating', ascending=False)
sorted_df_by_rating
# Out:
#      index      brand                                              Model  \
# 583    595        msi  MSI Vector GP68HX 13VH-072IN Gaming Laptop (13...
# 619    631       dell  Dell Alienware m16 Gaming Laptop (AMD Ryzen 9 ...
# 807    819       asus  Asus ROG Zephyrus G14 2023 GA402XZ-N2020WS Gam...
# 404    416        msi  MSI CreatorPro Z16 HX B13VKTO-214IN Laptop (13...
# 449    461     lenovo  Lenovo Legion Slim 7 16IRH8 82Y3007QIN Gaming ...
# ..     ...        ...                                                ...
# 486    498       asus  Asus Chromebook CX1400CKA-EK0257 Laptop (Celer...
# 169    180       asus  Asus Chromebook CX1500CKA-EJ0241 Laptop (Celer...
# 372    384  primebook  Primebook PBMTWIFI11064 Wi-Fi Laptop (MediaTek...
# 70      76  primebook  Primebook 4G Android Laptop (MediaTek Kompanio...
# 192    203        jio  Jio JioBook NB1112MM BLU 2023 Netbook Laptop (...
#
#       Price  Rating processor_brand processor_tier  num_cores  num_threads  \
# ...

# %%
medianLapR = sorted_df_by_rating['Rating'].median()
medianLapR
# Out:
# 64.0

# %% [markdown]
# Mode of the Prices and rating

# %%
modeLap = sorted_df_by_prices['Price'].mode()
modeLap
# Out:
# 0    34990
# 1    39990
# 2    46990
# 3    49990
# Name: Price, dtype: int64

# %%
modeLapR = sorted_df_by_rating['Rating'].mode()
modeLapR
# Out:
# 0    58
# Name: Rating, dtype: int64

# %% [markdown]
# **Sample variance**

# %%
varLap = sorted_df_by_prices['Price']
variance(varLap)
# Out:
# 3293027926.62801

# %% [markdown]
# Sample standard deviation

# %%
stdevLap = sorted_df_by_prices['Price']
stdev(varLap)
# Out:
# 57384.91026940802

# %% [markdown]
# I have only 50000 budget, I want to know my options:

# %%
df_laptop = laptop_df.query('Price >= 0 and Price <= 50000')
df_laptop
# Out:
#      index    brand                                              Model  Price  \
# 0        1    tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1        2    tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 3        4     acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4        5   lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
# 6        7  infinix  Infinix INBook Y2 Plus Laptop (11th Gen Core i...  34990
# ..     ...      ...                                                ...    ...
# 968    980     acer  Acer Aspire 3 A315-24P NX.KDESI.003 Laptop (Ry...  29990
# 969    981     asus  Asus Vivobook Go 14 2023 E1404FA-NK322WS Lapto...  32190
# 978    990      msi  MSI Modern 14 C13M-437IN Laptop (13th Gen Core...  40990
# 988   1000     asus  Asus Vivobook Go 15 2023 E1504FA-NJ522WS Lapto...  44990
# 990   1002       hp  HP Chromebook 15a-na0008TU Laptop (Intel Celer...  20990
#
# ...

# %% [markdown]
# I want to see the laptops that are beyond my budget:

# %%
df_laptop = laptop_df.query('Price >= 50000')
df_laptop
# Out:
#      index    brand                                              Model  Price  \
# 2        3       hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 5        6    apple  Apple MacBook Air 2020 MGND3HN Laptop (Apple M...  70990
# 9       10  infinix  Infinix Zerobook 2023 Laptop (13th Gen Core i9...  59990
# 11      12  samsung  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  64990
# 12      13      msi  MSI Thin GF63 12UC-846IN Gaming Laptop (12th G...  52990
# ..     ...      ...                                                ...    ...
# 984    996     asus  Asus Vivobook 16 2023 M1605YA-MB541WS Laptop (...  59990
# 985    997     acer  Acer Nitro 5 AN515-47 NH.QL3SI.003 Gaming Lapt...  75500
# 986    998     asus  Asus Vivobook Pro 15 M6500QC-HN542WS Laptop (R...  65990
# 987    999      msi  MSI Thin GF63 12VE-070IN Gaming Laptop (12th G...  91990
# 989   1001     asus  Asus Zenbook 14 2023 UM3402YA-KP541WS Laptop (...  67990
#
# ...

# %% [markdown]
# Now I want to know which one has touchscreen and has no touchscreen

# %%
Tlaptop= laptop_df[laptop_df['is_touch_screen'] == True]
Tlaptop
# Out:
#      index   brand                                              Model   Price  \
# 40      42    asus  Asus ROG Flow X13 GV301RC-LJ132WS Gaming Lapto...  113571
# 69      75      hp  HP Pavilion x360 14-ek1010TU Laptop (13th Gen ...   77899
# 100    106  lenovo  Lenovo Yoga 7 82YM0074IN Laptop (AMD Ryzen 7 7...   94990
# 127    135    asus  Asus ROG Flow X13 GV301RC-LJ073WS Gaming Lapto...   96389
# 132    140    asus  Asus Vivobook 15 Touch X515EA-EZ311WS Laptop (...   33490
# ..     ...     ...                                                ...     ...
# 938    950    dell  Dell XPS 9315 D560076WIN9S Laptop (12th Gen Co...  119600
# 952    964      hp  HP Chromebook x360 13b-ca0006MU Laptop (MediaT...   39551
# 971    983      lg  LG Gram 16T90Q-G.AH75A2 Laptop (12th Gen Core ...  118499
# 979    991      hp  HP Spectre x360 14-ef0075TU Laptop (12th Gen C...  154999
# 980    992    asus  Asus Vivobook Flip 14 2023 TN3402YAB-LZ522WS L...   54990
#
# ...

# %%
Flaptop= laptop_df[laptop_df['is_touch_screen'] == False]
Flaptop
# Out:
#      index   brand                                              Model  Price  \
# 0        1   tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1        2   tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2        3      hp  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  51100
# 3        4    acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4        5  lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
# ..     ...     ...                                                ...    ...
# 986    998    asus  Asus Vivobook Pro 15 M6500QC-HN542WS Laptop (R...  65990
# 987    999     msi  MSI Thin GF63 12VE-070IN Gaming Laptop (12th G...  91990
# 988   1000    asus  Asus Vivobook Go 15 2023 E1504FA-NJ522WS Lapto...  44990
# 989   1001    asus  Asus Zenbook 14 2023 UM3402YA-KP541WS Laptop (...  67990
# 990   1002      hp  HP Chromebook 15a-na0008TU Laptop (Intel Celer...  20990
#
# ...

# %%
laptop_df.describe()
# Out:
#              index          Price      Rating   num_cores  num_threads  \
# count   991.000000     991.000000  991.000000  991.000000   991.000000
# mean    505.860747   77266.504541   63.931382    8.128153    12.191726
# std     287.899458   57384.910269   10.190575    4.215499     5.585115
# min       1.000000    9800.000000   24.000000    2.000000     0.000000
# 25%     258.500000   43595.000000   58.000000    6.000000     8.000000
# 50%     507.000000   61900.000000   64.000000    8.000000    12.000000
# 75%     754.500000   89245.000000   71.000000   10.000000    16.000000
# max    1002.000000  454490.000000   89.000000   24.000000    32.000000
#
#        ram_memory  primary_storage_capacity  secondary_storage_capacity  \
# count  991.000000                991.000000                  991.000000
# mean    13.047427                610.938446                    4.004036
# std      5.591188                266.927666                   33.553936
# ...

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this seatwork I was able to refresh what I've learned from the Hand ons on Activity. Yet again, I've dived into data analysis using Python's pandas and NumPy libraries. I've learned to load, manipulate, and analyze datasets, computing statistics like mean, median, mode, and standard deviation but also making a Dataframe from certain columns and values
